# %% [markdown]
# ## AWS 이미지 업로드

# %%
import pandas as pd
import boto3
import requests
from urllib.parse import urlparse
import os
from tqdm import tqdm
from dotenv import load_dotenv

load_dotenv()

# AWS 인증 정보
aws_access_key_id = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY")
bucket_name = os.getenv("AWS_S3_BUCKET")
region_name = os.getenv("AWS_REGION")

# S3 클라이언트 생성
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# ✅ 1. CSV 파일에서 이미지 URL 10개 가져오기
df = pd.read_csv('text_image_combined_eda.csv')

# 이미지 URL과 Seq 있는 행 10개만 가져오기
#df_selected = df[['Seq', '이미지']].dropna().head(10)
df_selected = df[['Seq', '이미지']].dropna()

# Seq별로 그룹 나누기
for seq, group in df_selected.groupby('Seq'):
    # 그룹 내에서 인덱스를 1부터 시작하도록 재설정
    group = group.reset_index(drop=True)
    
    for idx, row in tqdm(group.iterrows(), total=len(group), desc=f"Seq {seq}"):
        url = row['이미지']
        # idx는 1부터 시작
        file_idx = idx + 1
        
        try:
            response = requests.get(url)
            response.raise_for_status()
            
            parsed_url = urlparse(url)
            ext = os.path.splitext(parsed_url.path)[1]  # 확장자 추출
            
            # 파일명: Seq_idx.ext (예: 123_1.jpg)
            file_name = f"{seq}_{file_idx}{ext}"
            s3_key = f"built_case_image/{file_name}"
            
            s3.put_object(
                Bucket=bucket_name,
                Key=s3_key,
                Body=response.content,
                ContentType=response.headers.get('Content-Type', 'image/jpeg')
            )
            
            print(f"✅ Uploaded: {s3_key}")
        
        except Exception as e:
            print(f"❌ Failed to upload {url}: {e}")
# Out:
# Seq 7453:  50%|█████     | 1/2 [00:01<00:01,  1.10s/it]
# ✅ Uploaded: built_case_image/7453_1.jpg
# Seq 7453: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# ✅ Uploaded: built_case_image/7453_2.jpg
# Seq 7476:  50%|█████     | 1/2 [00:02<00:02,  2.16s/it]
# ✅ Uploaded: built_case_image/7476_1.jpg
# Seq 7476: 100%|██████████| 2/2 [00:05<00:00,  2.54s/it]
# ✅ Uploaded: built_case_image/7476_2.jpg
# Seq 7490:  33%|███▎      | 1/3 [00:00<00:00,  3.18it/s]
# ✅ Uploaded: built_case_image/7490_1.webp
# Seq 7490:  67%|██████▋   | 2/3 [00:01<00:00,  1.73it/s]
# ✅ Uploaded: built_case_image/7490_2.jpg
# Seq 7490: 100%|██████████| 3/3 [00:01<00:00,  1.61it/s]
# ✅ Uploaded: built_case_image/7490_3.jpg
# Seq 7505: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# ✅ Uploaded: built_case_image/7505_1.jpg
# Seq 7658:  14%|█▍        | 1/7 [00:00<00:03,  1.98it/s]
# ✅ Uploaded: built_case_image/7658_1.jpg
# Seq 7658:  29%|██▊       | 2/7 [00:00<00:02,  2.28it/s]
# ...
